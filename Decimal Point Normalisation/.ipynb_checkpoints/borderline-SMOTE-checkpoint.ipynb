# %% [markdown]
# # borderline-SMOTE

# %% [markdown]
# 1. Random Forest Classifier
# 2. Bagging Classifier
# 3. XGBoost
# 4. Gradient Boosting
# 5. Extra Trees
# 6. Gaussian Naïve Bayes
# 7. CART
# 8. KNN
# 9. AdaBoost

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from time import time
import warnings

warnings.filterwarnings("ignore")

# reading the file
df = pd.read_csv("../dataset/all_three.csv")

## Droping the first column because it is of no use  
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# Seagreagting the features and labels 
Y = df[['label']]
X = df[['rec/sent','amount','size','weight','version','lock_time','is_coinbase','has_witness','input_count','output_count','input_total_usd','output_total_usd','fee_usd','fee_per_kb_usd','fee_per_kwu_usd','cdd_total']]

for x in X : 
    p = df[x].max()
    q = len(str(abs(p)))
    X[x] = X[x]/10**q 

# Spliting the Data 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.4) 

# Over sampling the training data
from imblearn.over_sampling import BorderlineSMOTE
Borderline_SMOTE = BorderlineSMOTE() 
x_train, y_train = Borderline_SMOTE.fit_resample(x_train, y_train)

# function to check the prediction and give total runtime
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from seaborn import heatmap
def check_prediction(y_true, y_pred, start_time) : 
    print(f"Time taken = {time()-start_time} seconds")
    print('accuracy_score:', accuracy_score(y_true, y_pred)) 
    print('confusion_matrix:\n', confusion_matrix(y_true, y_pred)) 
    print('classification_report:\n', classification_report(y_true, y_pred))
    print(heatmap(data=confusion_matrix(y_true, y_pred), annot=True))

# %%
df['label'].value_counts()
print("training data size")
print(y_train.value_counts())
print("testing data size")
print(y_test.value_counts())
# Out:
# training data size
# label
# 0        201542
# 1        201542
# 2        201542
# 3        201542
# Name: count, dtype: int64
# testing data size
# label
# 0        134305
# 2         22249
# 3         13597
# 1           899
# Name: count, dtype: int64

# %%
pf2=pd.DataFrame({'label':df['label'].value_counts().to_list()},
                    index=['Exchanges','Gambling', 'Mixing','Services'])

plt=pf2.plot.pie(y='label',autopct='%1.1f%%',figsize=(5,5))

# %% [markdown]
# ## Random Forest Classifier

# %%
current_time = time() 

from sklearn.ensemble import RandomForestClassifier 
model = RandomForestClassifier() 
model.fit(x_train, y_train.values.ravel()) 

# predicting the model in testing dataset
y_pred = model.predict(x_test)

# Evaluating the model 
check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 172.18453645706177 seconds
# accuracy_score: 0.8766501023092663
# confusion_matrix:
#  [[114319   7329    280  12377]
#  [   204    663     23      9]
#  [    31      6  22212      0]
#  [   725     49     66  12757]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.85      0.92    134305
#            1       0.08      0.74      0.15       899
#            2       0.98      1.00      0.99     22249
#            3       0.51      0.94      0.66     13597
#
#     accuracy                           0.88    171050
#    macro avg       0.64      0.88      0.68    171050
# weighted avg       0.95      0.88      0.90    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Bagging Classifier

# %%
# Bagging Classifier
current_time = time()

# Initializing the base classifier
from sklearn.tree import DecisionTreeClassifier
base_model = DecisionTreeClassifier()

# number  of base classifier
n_trees = 50

# initializing the bagging classifier 
from sklearn.ensemble import BaggingClassifier
model = BaggingClassifier(base_estimator = base_model,random_state = 50)

# Cross validation score
from sklearn.model_selection import KFold
kfold = KFold(n_splits = 3,random_state =None)

from sklearn.model_selection import cross_val_score
res = cross_val_score(model, X, Y.values.ravel(), cv = kfold)

model.fit(x_train,y_train.values.ravel())

y_pred = model.predict(x_test)

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 114.58328652381897 seconds
# accuracy_score: 0.8828821981876644
# confusion_matrix:
#  [[115454   6809    119  11923]
#  [   214    667      6     12]
#  [    43      1  22203      2]
#  [   881     22      1  12693]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92    134305
#            1       0.09      0.74      0.16       899
#            2       0.99      1.00      1.00     22249
#            3       0.52      0.93      0.66     13597
#
#     accuracy                           0.88    171050
#    macro avg       0.65      0.88      0.68    171050
# weighted avg       0.95      0.88      0.91    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## XGBoost

# %%
current_time = time()
# XGBoost without Hyper Parameter tuning

# Initializing the classifier
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(x_train, y_train)

# Predicting the test dataset
y_pred = model.predict(x_test)

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 16.01325297355652 seconds
# accuracy_score: 0.9271382636655948
# confusion_matrix:
#  [[122844   1445     11  10005]
#  [   219    662      0     18]
#  [     6      1  22242      0]
#  [   725     31      2  12839]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95    134305
#            1       0.31      0.74      0.44       899
#            2       1.00      1.00      1.00     22249
#            3       0.56      0.94      0.70     13597
#
#     accuracy                           0.93    171050
#    macro avg       0.72      0.90      0.77    171050
# weighted avg       0.96      0.93      0.94    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Gradient Boosting

# %%
current_time = time()

from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()

model.fit(x_train, y_train)  

y_pred = model.predict(x_test) 

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 1299.9139261245728 seconds
# accuracy_score: 0.8313300204618532
# confusion_matrix:
#  [[107083  11288   1906  14028]
#  [   159    272    394     74]
#  [    11     14  22222      2]
#  [   671    183    121  12622]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.80      0.88    134305
#            1       0.02      0.30      0.04       899
#            2       0.90      1.00      0.95     22249
#            3       0.47      0.93      0.63     13597
#
#     accuracy                           0.83    171050
#    macro avg       0.60      0.76      0.63    171050
# weighted avg       0.93      0.83      0.87    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Extra Trees

# %%
current_time = time()

# Initialize the Extra Trees classifier with some hyperparameters
from sklearn.ensemble import ExtraTreesClassifier
clf = ExtraTreesClassifier(
    n_estimators=100, 
    max_depth=5, 
    random_state=42
)

# Train the model on the training data
clf.fit(x_train, y_train)

# Predict the classes of the test data
y_pred = clf.predict(x_test)

# Evaluate the F1-score of the model
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average='weighted')
print("F1-score:", f1_score)

check_prediction(y_test, y_pred, current_time)
# Out:
# F1-score: <function f1_score at 0x0000020995035440>
# Time taken = 16.620936155319214 seconds
# accuracy_score: 0.7684712072493423
# confusion_matrix:
#  [[97388 25427   132 11358]
#  [  120   267   368   144]
#  [    2    42 22205     0]
#  [  766  1234    10 11587]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.73      0.84    134305
#            1       0.01      0.30      0.02       899
#            2       0.98      1.00      0.99     22249
#            3       0.50      0.85      0.63     13597
#
#     accuracy                           0.77    171050
#    macro avg       0.62      0.72      0.62    171050
# weighted avg       0.95      0.77      0.84    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Gaussian Naïve Bayes

# %%
current_time = time()
from sklearn.naive_bayes import GaussianNB 
model = GaussianNB() 

model.fit(x_train, y_train) 

y_pred = model.predict(x_test) 

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 0.46210336685180664 seconds
# accuracy_score: 0.16309850920783397
# confusion_matrix:
#  [[15733 48517  1419 68636]
#  [   20   361     3   515]
#  [    2    56   166 22025]
#  [  196  1713    50 11638]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.12      0.21    134305
#            1       0.01      0.40      0.01       899
#            2       0.10      0.01      0.01     22249
#            3       0.11      0.86      0.20     13597
#
#     accuracy                           0.16    171050
#    macro avg       0.30      0.35      0.11    171050
# weighted avg       0.80      0.16      0.18    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Classification and Regression Trees (CART)

# %%
current_time = time()
# create a decision tree classifier with max depth of 3
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=3)

# fit the model to the training data
clf.fit(x_train, y_train)

# make predictions on the testing data
y_pred = clf.predict(x_test)

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 2.624661684036255 seconds
# accuracy_score: 0.782987430575855
# confusion_matrix:
#  [[99582  8663 10040 16020]
#  [  169   116   445   169]
#  [   20     0 22229     0]
#  [  991   306   297 12003]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.74      0.85    134305
#            1       0.01      0.13      0.02       899
#            2       0.67      1.00      0.80     22249
#            3       0.43      0.88      0.57     13597
#
#     accuracy                           0.78    171050
#    macro avg       0.53      0.69      0.56    171050
# weighted avg       0.90      0.78      0.82    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## K-Nearest Neighbours

# %%
current_time = time()

from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors=3) 

knn.fit(x_train, y_train) 

y_pred = knn.predict(x_test) 

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 103.6182029247284 seconds
# accuracy_score: 0.9371704180064309
# confusion_matrix:
#  [[126887    731    183   6504]
#  [   277    606      3     13]
#  [    37      0  22208      4]
#  [  2955     15     25  10602]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96    134305
#            1       0.45      0.67      0.54       899
#            2       0.99      1.00      0.99     22249
#            3       0.62      0.78      0.69     13597
#
#     accuracy                           0.94    171050
#    macro avg       0.76      0.85      0.80    171050
# weighted avg       0.95      0.94      0.94    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ##  Adaboost

# %%
current_time = time()

from sklearn import metrics
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier


# Initializing  adaboost classifier model

adboost = AdaBoostClassifier()
adboost = adboost.fit(x_train,y_train)

y_pred = adboost.predict(x_test)
check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 66.89127206802368 seconds
# accuracy_score: 0.6864425606547793
# confusion_matrix:
#  [[95780 17044  8410 13071]
#  [  150   189    43   517]
#  [  120    10 11576 10543]
#  [  781   970  1975  9871]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.71      0.83    134305
#            1       0.01      0.21      0.02       899
#            2       0.53      0.52      0.52     22249
#            3       0.29      0.73      0.41     13597
#
#     accuracy                           0.69    171050
#    macro avg       0.45      0.54      0.45    171050
# weighted avg       0.87      0.69      0.75    171050
#
# Axes(0.125,0.11;0.62x0.77)
