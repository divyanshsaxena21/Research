# %% [markdown]
# - RAM : 16GB
# - Processor : i5 1240p

# %% [markdown]
# - Ensemble Balanceing Techniques:
#     - Balanced Random forest Classifier
#     - Balanced Bagging Classifier
#     - RUS Boost Classifier (Boosting)
#     - Easy Ensemble Classiifer (Balanced Ada Boost Classifier)

# %% [markdown]
# # Balanced Ensambles

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from time import time
import warnings

warnings.filterwarnings("ignore")


# reading the file
df = pd.read_csv("../dataset/all_three.csv")

## Droping the first column because it is of no use  
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# Seagreagting the features and labels 
Y = df[['label']]
X = df[['rec/sent','amount','size','weight','version','lock_time','is_coinbase','has_witness','input_count','output_count','input_total_usd','output_total_usd','fee_usd','fee_per_kb_usd','fee_per_kwu_usd','cdd_total']]

for x in X : 
    p = df[x].max()
    q = len(str(abs(p)))
    X[x] = X[x]/10**q 
    

# Spliting the Data 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.4) 

# Over sampling the training data
from imblearn.over_sampling import ADASYN
ADASYN_ = ADASYN() 
x_train, y_train = ADASYN_.fit_resample(x_train, y_train)

# %%
# function to check the prediction and give total runtime
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from seaborn import heatmap
def check_prediction(y_true, y_pred, start_time) : 
    print(f"Time taken = {time()-start_time} seconds")
    print('accuracy_score:', accuracy_score(y_true, y_pred)) 
    print('confusion_matrix:\n', confusion_matrix(y_true, y_pred)) 
    print('classification_report:\n', classification_report(y_true, y_pred))
    print(heatmap(data=confusion_matrix(y_true, y_pred), annot=True))

# %%
df['label'].value_counts()
print("training data size")
print(y_train.value_counts())
print("testing data size")
print(y_test.value_counts())
# Out:
# training data size
# label
# 3        204612
# 2        201492
# 0        201471
# 1        201391
# Name: count, dtype: int64
# testing data size
# label
# 0        134376
# 2         22143
# 3         13625
# 1           906
# Name: count, dtype: int64

# %%
pf2=pd.DataFrame({'label':df['label'].value_counts().to_list()},
                    index=['Exchanges','Gambling', 'Mixing','Services'])

plt=pf2.plot.pie(y='label',autopct='%1.1f%%',figsize=(5,5))

# %% [markdown]
# ## Balanced Random Forest Classifier

# %%
start_time = time()
from imblearn.ensemble import BalancedRandomForestClassifier 
model = BalancedRandomForestClassifier(n_jobs=-1) 
model.fit(x_train, y_train) 

# predicting the model in testing dataset
y_pred = model.predict(x_test)

# Evaluating the model 
check_prediction(y_test, y_pred, start_time)
# Out:
# Time taken = 273.46260118484497 seconds
# accuracy_score: 0.8198421514177141
# confusion_matrix:
#  [[104482  15758   1162  12974]
#  [   103    749     43     11]
#  [     4      5  22134      0]
#  [   497    172     87  12869]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.78      0.87    134376
#            1       0.04      0.83      0.09       906
#            2       0.94      1.00      0.97     22143
#            3       0.50      0.94      0.65     13625
#
#     accuracy                           0.82    171050
#    macro avg       0.62      0.89      0.65    171050
# weighted avg       0.94      0.82      0.86    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Balanced Bagging Classifier

# %%
start_time = time()
# Bagging Classifier

# Initializing the base classifier
from sklearn.tree import DecisionTreeClassifier
base_model = DecisionTreeClassifier()

# number  of base classifier
n_trees = 50

# initializing the bagging classifier 
from imblearn.ensemble import BalancedBaggingClassifier
model = BalancedBaggingClassifier(estimator = base_model,random_state = 50)

# Cross validation score
from sklearn.model_selection import KFold
kfold = KFold(n_splits = 3,random_state =None)

from sklearn.model_selection import cross_val_score
res = cross_val_score(model, X, Y.values.ravel(), cv = kfold)

model.fit(x_train,y_train.values.ravel())

y_pred = model.predict(x_test)

check_prediction(y_test, y_pred, start_time)
# Out:
# Time taken = 131.64850687980652 seconds
# accuracy_score: 0.867939199064601
# confusion_matrix:
#  [[113005   9211     66  12139]
#  [   195    722      1     10]
#  [    25      6  22135      0]
#  [   820    112      4  12599]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91    134421
#            1       0.07      0.78      0.13       928
#            2       1.00      1.00      1.00     22166
#            3       0.51      0.93      0.66     13535
#
#     accuracy                           0.87    171050
#    macro avg       0.64      0.89      0.67    171050
# weighted avg       0.95      0.87      0.90    171050
#
# Axes(0.125,0.11;0.62x0.77)
# ' \n8s\naccuracy_score: 0.9579187372113417\nconfusion_matrix:\n [[63706    12     3  3504]\n [    0   429     0     0]\n [    1    13 11122     4]\n [   48    12     2  6669]]\nclassification_report:\n               precision    recall  f1-score   support\n\n           0       1.00      0.95      0.97     67225\n           1       0.92      1.00      0.96       429\n           2       1.00      1.00      1.00     11140\n           3       0.66      0.99      0.79      6731\n\n    accuracy                           0.96     85525\n   macro avg       0.89      0.98      0.93     85525\nweighted avg       0.97      0.96      0.96     85525\n'

# %% [markdown]
# ## RUS Boost Classifier (Boosting)

# %%
start_time = time()

from imblearn.ensemble import RUSBoostClassifier 
model = RUSBoostClassifier(n_estimators=4, random_state=42) 
model.fit(x_train, y_train.values.ravel()) 
check_prediction(y_test, model.predict(x_test), start_time)
# Out:
# Time taken = 6.962093830108643 seconds
# accuracy_score: 0.6408535515931014
# confusion_matrix:
#  [[90300 13297 19828 10996]
#  [  130   136   126   536]
#  [  170     0  7740 14256]
#  [  392   789   912 11442]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.67      0.80    134421
#            1       0.01      0.15      0.02       928
#            2       0.27      0.35      0.30     22166
#            3       0.31      0.85      0.45     13535
#
#     accuracy                           0.64    171050
#    macro avg       0.39      0.50      0.39    171050
# weighted avg       0.84      0.64      0.70    171050
#
# Axes(0.125,0.11;0.62x0.77)
# ' \n1s\naccuracy_score: 0.7136159017831043\nconfusion_matrix:\n [[45571   116    53 21485]\n [  102   325     2     0]\n [    0   839 10189   112]\n [ 1326   449     9  4947]]\nclassification_report:\n               precision    recall  f1-score   support\n\n           0       0.97      0.68      0.80     67225\n           1       0.19      0.76      0.30       429\n           2       0.99      0.91      0.95     11140\n           3       0.19      0.73      0.30      6731\n\n    accuracy                           0.71     85525\n   macro avg       0.58      0.77      0.59     85525\nweighted avg       0.91      0.71      0.78     85525\n'

# %% [markdown]
# ## Easy Ensemble Classiifer (Balanced Ada Boost Classifier)

# %%
start_time = time() 
from imblearn.ensemble import EasyEnsembleClassifier

model = EasyEnsembleClassifier(n_estimators=4, random_state=42) 

model.fit(x_train, y_train.values.ravel()) 

check_prediction(y_test, model.predict(x_test), start_time)
# Out:
# Time taken = 322.2325088977814 seconds
# accuracy_score: 0.5672025723472669
# confusion_matrix:
#  [[79119 32899  9900 12503]
#  [  137   218    76   497]
#  [    1     6  7657 14502]
#  [  213  1211  2085 10026]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.59      0.74    134421
#            1       0.01      0.23      0.01       928
#            2       0.39      0.35      0.37     22166
#            3       0.27      0.74      0.39     13535
#
#     accuracy                           0.57    171050
#    macro avg       0.41      0.48      0.38    171050
# weighted avg       0.85      0.57      0.66    171050
#
# Axes(0.125,0.11;0.62x0.77)
# '\n5.2s\nAccuracy_score: 0.9010230926629641\nconfusion_matrix:\n [[63751    79    82  3085]\n [    0   442     3     0]\n [    0    56 10978    69]\n [ 5028    35    28  1889]]\nclassification_report:\n               precision    recall  f1-score   support\n\n           0       0.93      0.95      0.94     66997\n           1       0.72      0.99      0.84       445\n           2       0.99      0.99      0.99     11103\n           3       0.37      0.27      0.31      6980\n\n    accuracy                           0.90     85525\n   macro avg       0.75      0.80      0.77     85525\nweighted avg       0.89      0.90      0.89     85525\n'
