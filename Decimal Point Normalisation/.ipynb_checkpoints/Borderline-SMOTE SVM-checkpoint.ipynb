# %% [markdown]
# # Borderline-SMOTE SVM

# %% [markdown]
# 1. Random Forest Classifier
# 2. Bagging Classifier
# 3. XGBoost
# 4. Gradient Boosting
# 5. Extra Trees
# 6. Gaussian Naïve Bayes
# 7. CART
# 8. KNN
# 9. AdaBoost

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from time import time
import warnings

warnings.filterwarnings("ignore")

# reading the file
df = pd.read_csv("../dataset/all_three.csv")

## Droping the first column because it is of no use  
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# Seagreagting the features and labels 
Y = df[['label']]
X = df[['rec/sent','amount','size','weight','version','lock_time','is_coinbase','has_witness','input_count','output_count','input_total_usd','output_total_usd','fee_usd','fee_per_kb_usd','fee_per_kwu_usd','cdd_total']]

for x in X : 
    p = df[x].max()
    q = len(str(abs(p)))
    X[x] = X[x]/10**q 

# Spliting the Data 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.4) 

# Over sampling the training data
from imblearn.over_sampling import SVMSMOTE
SVM_SMOTE = SVMSMOTE(n_jobs=-1) 
x_train, y_train = SVM_SMOTE.fit_resample(x_train, y_train)

# function to check the prediction and give total runtime
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from seaborn import heatmap
def check_prediction(y_true, y_pred, start_time) : 
    print(f"Time taken = {time()-start_time} seconds")
    print('accuracy_score:', accuracy_score(y_true, y_pred)) 
    print('confusion_matrix:\n', confusion_matrix(y_true, y_pred)) 
    print('classification_report:\n', classification_report(y_true, y_pred))
    print(heatmap(data=confusion_matrix(y_true, y_pred), annot=True))

# %%
df['label'].value_counts()
print("training data size")
print(y_train.value_counts())
print("testing data size")
print(y_test.value_counts())
# Out:
# training data size
# label
# 0        201480
# 1        201480
# 2        201480
# 3        201480
# Name: count, dtype: int64
# testing data size
# label
# 0        134367
# 2         22144
# 3         13630
# 1           909
# Name: count, dtype: int64

# %%
pf2=pd.DataFrame({'label':df['label'].value_counts().to_list()},
                    index=['Exchanges','Gambling', 'Mixing','Services'])

plt=pf2.plot.pie(y='label',autopct='%1.1f%%',figsize=(5,5))

# %% [markdown]
# ## Random Forest Classifier

# %%
current_time = time() 

from sklearn.ensemble import RandomForestClassifier 
model = RandomForestClassifier() 
model.fit(x_train, y_train) 

# predicting the model in testing dataset
y_pred = model.predict(x_test)

# Evaluating the model 
check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 158.13941264152527 seconds
# accuracy_score: 0.8737445191464485
# confusion_matrix:
#  [[113847   8473    253  11794]
#  [   181    720      6      2]
#  [    14      4  22125      1]
#  [   797     59     12  12762]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.85      0.91    134367
#            1       0.08      0.79      0.14       909
#            2       0.99      1.00      0.99     22144
#            3       0.52      0.94      0.67     13630
#
#     accuracy                           0.87    171050
#    macro avg       0.64      0.89      0.68    171050
# weighted avg       0.95      0.87      0.90    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Bagging Classifier

# %%
# Bagging Classifier
current_time = time()

# Initializing the base classifier
from sklearn.tree import DecisionTreeClassifier
base_model = DecisionTreeClassifier()

# number  of base classifier
n_trees = 50

# initializing the bagging classifier 
from sklearn.ensemble import BaggingClassifier
model = BaggingClassifier(base_estimator = base_model,random_state = 50, n_jobs=-1)

# Cross validation score
from sklearn.model_selection import KFold
kfold = KFold(n_splits = 3,random_state =None)

from sklearn.model_selection import cross_val_score
res = cross_val_score(model, X, Y.values.ravel(), cv = kfold)

model.fit(x_train,y_train)

y_pred = model.predict(x_test)

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 18.637147665023804 seconds
# accuracy_score: 0.8797486115171003
# confusion_matrix:
#  [[115153   7832    111  11271]
#  [   194    703      3      9]
#  [    24      0  22119      1]
#  [  1092     31      1  12506]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92    134367
#            1       0.08      0.77      0.15       909
#            2       0.99      1.00      1.00     22144
#            3       0.53      0.92      0.67     13630
#
#     accuracy                           0.88    171050
#    macro avg       0.65      0.89      0.68    171050
# weighted avg       0.95      0.88      0.90    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## XGBoost

# %%
current_time = time()
# XGBoost without Hyper Parameter tuning

# Initializing the classifier
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(x_train, y_train)

# Predicting the test dataset
y_pred = model.predict(x_test)

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 12.762350082397461 seconds
# accuracy_score: 0.9326220403390821
# confusion_matrix:
#  [[123971   1998     10   8388]
#  [   188    714      0      7]
#  [     4      2  22137      1]
#  [   874     53      0  12703]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96    134367
#            1       0.26      0.79      0.39       909
#            2       1.00      1.00      1.00     22144
#            3       0.60      0.93      0.73     13630
#
#     accuracy                           0.93    171050
#    macro avg       0.71      0.91      0.77    171050
# weighted avg       0.96      0.93      0.94    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Gradient Boosting

# %%
current_time = time()

from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()

model.fit(x_train, y_train)  

y_pred = model.predict(x_test) 

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 1397.5096216201782 seconds
# accuracy_score: 0.8427945045308389
# confusion_matrix:
#  [[108913  11496   1468  12490]
#  [   154    720     34      1]
#  [     1     12  22129      2]
#  [   762    401     69  12398]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.81      0.89    134367
#            1       0.06      0.79      0.11       909
#            2       0.93      1.00      0.97     22144
#            3       0.50      0.91      0.64     13630
#
#     accuracy                           0.84    171050
#    macro avg       0.62      0.88      0.65    171050
# weighted avg       0.94      0.84      0.88    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Extra Trees

# %%
current_time = time()

# Initialize the Extra Trees classifier with some hyperparameters
from sklearn.ensemble import ExtraTreesClassifier
clf = ExtraTreesClassifier(
    n_estimators=100, 
    max_depth=5, 
    random_state=42
)

# Train the model on the training data
clf.fit(x_train, y_train)

# Predict the classes of the test data
y_pred = clf.predict(x_test)

# Evaluate the F1-score of the model
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average='weighted')
print("F1-score:", f1_score)

check_prediction(y_test, y_pred, current_time)
# Out:
# F1-score: <function f1_score at 0x0000023106045440>
# Time taken = 18.216538429260254 seconds
# accuracy_score: 0.7830751242326806
# confusion_matrix:
#  [[99696 22840   452 11379]
#  [  124   398   233   154]
#  [    1    35 22108     0]
#  [  815   988    84 11743]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.74      0.85    134367
#            1       0.02      0.44      0.03       909
#            2       0.97      1.00      0.98     22144
#            3       0.50      0.86      0.64     13630
#
#     accuracy                           0.78    171050
#    macro avg       0.62      0.76      0.62    171050
# weighted avg       0.94      0.78      0.84    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Gaussian Naïve Bayes

# %%
current_time = time()
from sklearn.naive_bayes import GaussianNB 
model = GaussianNB() 

model.fit(x_train, y_train) 

y_pred = model.predict(x_test) 

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 0.43372368812561035 seconds
# accuracy_score: 0.10878105817012569
# confusion_matrix:
#  [[ 15657 114044    737   3929]
#  [    20    884      2      3]
#  [   648  21133    363      0]
#  [   235  11664     28   1703]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.12      0.21    134367
#            1       0.01      0.97      0.01       909
#            2       0.32      0.02      0.03     22144
#            3       0.30      0.12      0.18     13630
#
#     accuracy                           0.11    171050
#    macro avg       0.39      0.31      0.11    171050
# weighted avg       0.81      0.11      0.18    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## Classification and Regression Trees (CART)

# %%
current_time = time()
# create a decision tree classifier with max depth of 3
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=3)

# fit the model to the training data
clf.fit(x_train, y_train)

# make predictions on the testing data
y_pred = clf.predict(x_test)

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 2.66420841217041 seconds
# accuracy_score: 0.6954925460391699
# confusion_matrix:
#  [[84379 19347 13843 16798]
#  [   84   690   112    23]
#  [    1   173 21970     0]
#  [  475   641   589 11925]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.63      0.77    134367
#            1       0.03      0.76      0.06       909
#            2       0.60      0.99      0.75     22144
#            3       0.41      0.87      0.56     13630
#
#     accuracy                           0.70    171050
#    macro avg       0.51      0.81      0.54    171050
# weighted avg       0.89      0.70      0.75    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ## K-Nearest Neighbours

# %%
current_time = time()

from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors=3) 

knn.fit(x_train, y_train) 

y_pred = knn.predict(x_test) 

check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 93.34465169906616 seconds
# accuracy_score: 0.940719087985969
# confusion_matrix:
#  [[127688    849    275   5555]
#  [   261    639      3      6]
#  [    21      2  22120      1]
#  [  3085     35     47  10463]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96    134367
#            1       0.42      0.70      0.53       909
#            2       0.99      1.00      0.99     22144
#            3       0.65      0.77      0.71     13630
#
#     accuracy                           0.94    171050
#    macro avg       0.76      0.85      0.80    171050
# weighted avg       0.95      0.94      0.94    171050
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ##  Adaboost

# %%
current_time = time()

from sklearn import metrics
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier


# Initializing  adaboost classifier model

adboost = AdaBoostClassifier()
adboost = adboost.fit(x_train,y_train)

y_pred = adboost.predict(x_test)
check_prediction(y_test, y_pred, current_time)
# Out:
# Time taken = 75.24138307571411 seconds
# accuracy_score: 0.7837240572931892
# confusion_matrix:
#  [[100315  17276   5677  11099]
#  [   143    369     68    329]
#  [     6     17  22120      1]
#  [   842   1032    504  11252]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.75      0.85    134367
#            1       0.02      0.41      0.04       909
#            2       0.78      1.00      0.88     22144
#            3       0.50      0.83      0.62     13630
#
#     accuracy                           0.78    171050
#    macro avg       0.57      0.74      0.60    171050
# weighted avg       0.92      0.78      0.83    171050
#
# Axes(0.125,0.11;0.62x0.77)
